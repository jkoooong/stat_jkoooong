# %% [markdown]
# # 1. Selenium을 활용하여 크롤링하기

# %% [markdown]
# ## 목표 : 멜론 사이트 멜론차트 TOP100 결과를 크롤링하여 데이터프레임으로 저장해보자!

# %%
from selenium import webdriver
import time
import pandas as pd

# %% [markdown]
# ### 1) 멜론 사이트에 접속하여 검색어 입력하고 클릭하기

# %%
#자신의 chromedriver가 있는 파일 위치 경로 기억하기
#window는 ~/chromedriver.exe를 불러오고 mac은 ~/chromedriver를 불러오기
path = "C:/Users/Downloads/chromedriver_win32/chromedriver.exe"

# %%
#selenium으로 제어할 수 있는 크롬 브라우저 창이 뜬다.
driver = webdriver.Chrome(path)

# %%
#웹 페이지 접속하기
url = 'https://www.melon.com/'
#webdriver가 멜론사이트에 접속하도록 명령
driver.get(url)

# %%
#검색창 element 찾기
#현재 열려 있는 창의 element의 id가 'top_search'인 것을 찾아서 element 변수에 할당
element = driver.find_element_by_id('top_search')

# %%
#검색어 입력하기
element.clear()
element.send_keys('방탄소년단')

# %%
#검색 클릭하기
finder = driver.find_element_by_css_selector('.search_m')
finder.click()

# %%
#검색 클릭하기
finder = driver.find_element_by_css_selector('.menu01.mlog')
finder.click()

# %% [markdown]
# ### 2) TOP50 곡들의 곡명, 아티스트 이름을 크롤링해서 프린트하기

# %%
for i in range(50):
    print('곡명 : ', driver.find_elements_by_css_selector('.lst50 .wrap_song_info .rank01')[i].text)
    print('아티스트 : ', driver.find_elements_by_css_selector('.lst50 .wrap_song_info .rank02')[i].text)
# Out:
# 곡명 :  안녕
# 아티스트 :  폴킴
# 곡명 :  Done For Me
# 아티스트 :  펀치 (Punch)
# 곡명 :  기억해줘요 내 모든 날과 그때를
# 아티스트 :  거미
# 곡명 :  오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)
# 아티스트 :  마크툽 (MAKTUB)
# 곡명 :  그대라는 시
# 아티스트 :  태연 (TAEYEON)
# 곡명 :  내 목소리 들리니
# 아티스트 :  벤
# 곡명 :  니 소식
# 아티스트 :  송하예
# 곡명 :  포장마차
# 아티스트 :  황인욱
# 곡명 :  음파음파 (Umpah Umpah)
# 아티스트 :  Red Velvet (레드벨벳)
# 곡명 :  술이 문제야
# 아티스트 :  장혜진, 윤민수(바이브)
# 곡명 :  내 맘을 볼 수 있나요
# 아티스트 :  헤이즈 (Heize)
# 곡명 :  시든 꽃에 물을 주듯
# 아티스트 :  HYNN(박혜원)
# 곡명 :  헤어져줘서 고마워
# 아티스트 :  벤
# 곡명 :  나의 어깨에 기대어요
# 아티스트 :  10cm
# 곡명 :  2002
# 아티스트 :  Anne-Marie
# 곡명 :  ICY
# 아티스트 :  ITZY (있지)
# 곡명 :  사랑에 연습이 있었다면 (Prod. 2soo)
# 아티스트 :  임재현
# 곡명 :  작은 것들을 위한 시 (Boy With Luv) feat. Halsey
# 아티스트 :  방탄소년단
# 곡명 :  Another Day
# 아티스트 :  먼데이 키즈 (Monday Kiz), 펀치 (Punch)
# 곡명 :  bad guy
# 아티스트 :  Billie Eilish (빌리 아일리시)
# 곡명 :  Speechless (Full)
# 아티스트 :  Naomi Scott
# 곡명 :  Señorita
# 아티스트 :  Shawn Mendes, Camila Cabello
# 곡명 :  BAND
# 아티스트 :  창모 (CHANGMO), Hash Swan, ASH ISLAND, 김효은
# 곡명 :  솔직하게 말해서 나
# 아티스트 :  김나영
# 곡명 :  사랑이 식었다고 말해도 돼
# 아티스트 :  먼데이 키즈 (Monday Kiz)
# 곡명 :  인사
# 아티스트 :  멜로망스
# 곡명 :  Snapping
# 아티스트 :  청하
# 곡명 :  내 안부
# 아티스트 :  이우
# 곡명 :  Say Goodbye
# 아티스트 :  송하예
# 곡명 :  괜찮아도 괜찮아 (That`s okay)
# 아티스트 :  디오 (D.O.)
# 곡명 :  그 끝에 그대
# 아티스트 :  청하
# 곡명 :  너에게 못했던 내 마지막 말은
# 아티스트 :  다비치
# 곡명 :  make her dance (Feat. Loopy & Crush)
# 아티스트 :  사이먼 도미닉
# 곡명 :  We don`t talk together (Feat. 기리보이) (Prod. SUGA)
# 아티스트 :  헤이즈 (Heize)
# 곡명 :  아퍼 (Feat. Kid Milli, Lil tachi, 김승민, NO:EL, C JAMM)
# 아티스트 :  기리보이
# 곡명 :  사월이 지나면 우리 헤어져요 (Beautiful goodbye)
# 아티스트 :  첸 (CHEN)
# 곡명 :  모든 날, 모든 순간 (Every day, Every Moment)
# 아티스트 :  폴킴
# 곡명 :  너만 너만 너만
# 아티스트 :  양다일
# 곡명 :  UN Village
# 아티스트 :  백현 (BAEKHYUN)
# 곡명 :  사계 (Four Seasons)
# 아티스트 :  태연 (TAEYEON)
# 곡명 :  그때가 좋았어
# 아티스트 :  케이시 (Kassy)
# 곡명 :  노래방에서
# 아티스트 :  장범준
# 곡명 :  FANCY
# 아티스트 :  TWICE (트와이스)
# 곡명 :  Paris In The Rain
# 아티스트 :  Lauv
# 곡명 :  너를 만나
# 아티스트 :  폴킴
# 곡명 :  Love Shot
# 아티스트 :  EXO
# 곡명 :  달라달라
# 아티스트 :  ITZY (있지)
# 곡명 :  비가 내리는 날에는
# 아티스트 :  윤하 (YOUNHA)
# 곡명 :  주저하는 연인들을 위해
# 아티스트 :  잔나비
# 곡명 :  HIT
# 아티스트 :  세븐틴

# %% [markdown]
# ### 3) TOP100곡들의 상세정보 페이지 접속에 필요한 노래 아이디 가져오기

# %%
#TOP100 곡들의 song id 가져오기
song_ids_50 = driver.find_elements_by_css_selector('tr#lst50.lst50')
song_ids_50 = [song_id.get_attribute('data-song-no') for song_id in song_ids_50]
song_ids_100 = driver.find_elements_by_css_selector('tr#lst100.lst100')
song_ids_100 = [song_id.get_attribute('data-song-no') for song_id in song_ids_100]
song_ids = song_ids_50 + song_ids_100
print(song_ids)
# Out:
# ['31984204', '31993173', '31967064', '31853557', '31938460', '31983112', '31788850', '31873020', '31998495', '31870517', '31952592', '31703498', '31901475', '31938046', '31029291', '31955739', '31324607', '31737197', '31924110', '31701428', '31815967', '31877297', '31854689', '31854442', '31829536', '31914848', '31879867', '31929663', '31993356', '31893681', '31967092', '31804010', '32001574', '31908033', '31856628', '31706215', '30962526', '31952576', '31917677', '31688205', '31524320', '31684636', '31754579', '31341518', '31388145', '31492319', '31606729', '31899300', '31666417', '31969026', '31947079', '30244931', '31777113', '31532642', '31969182', '30227238', '31972338', '31266290', '31737198', '31532656', '31399721', '31151836', '31982782', '8235260', '31815962', '31890067', '31939397', '31532438', '31709523', '31864770', '31872859', '31532643', '8252573', '31717822', '31788828', '31835421', '31798464', '31737199', '31920854', '31895208', '31907388', '31939398', '31737202', '31621518', '31175119', '31304766', '31947081', '31570736', '31815490', '31189085', '32001519', '31947078', '31841027', '31709524', '31951249', '31947080', '31788110', '31655897', '31947077', '31999275']

# %% [markdown]
# ### 4) 곡명, 아티스트, 앨범명, 발매일, 장르, 좋아요 수, 리뷰 수를 크롤링하여 프린트하기

# %%
#1위곡 상세정보 페이지 접속
url = 'https://www.melon.com/song/detail.htm?songId=' + song_ids[0]
driver.get(url)

# %%
print('곡명 : ' ,driver.find_element_by_css_selector('.song_name').text)
print('아티스트 : ',driver.find_element_by_css_selector('.artist').text)

for i in range(3):
    if i == 0:
        print('앨범명 : ',driver.find_elements_by_css_selector('.list dd')[i].text)
    elif i ==1:
        print('발매일 : ',driver.find_elements_by_css_selector('.list dd')[i].text)
    else:
        print('장르 : ',driver.find_elements_by_css_selector('.list dd')[i].text)
        
print('좋아요 갯수 : ', driver.find_element_by_css_selector('#d_like_count').text)
print('리뷰 갯수 : ',driver.find_element_by_css_selector('.d_cmtpgn_srch_cnt').text)
# Out:
# 곡명 :  안녕
# 아티스트 :  폴킴
# 앨범명 :  호텔 델루나 OST Part.10
# 발매일 :  2019.08.12
# 장르 :  발라드, 국내드라마
# 좋아요 갯수 :  57,472
# 리뷰 갯수 :  253

# %% [markdown]
# ### 5) 멜론차트 TOP100 곡 상세정보를 데이터프레임에 저장하기

# %% [markdown]
# #### 주의! Stale Element Reference Exception 에러
# - 내용
#     - 1. The element has been deleted entirely.
#     - 2. The element is no longer attached to the DOM.
# - 해결
#     - 1. time.sleep을 통한 명시적 대기
#     - 2. driver.implicitly_wait

# %%
result = list()

for i in range(len(song_ids)):
    
    #명시적 대기
    time.sleep(3)
    
    #곡 상세정보 페이지 접속
    url = 'https://www.melon.com/song/detail.htm?songId=' + song_ids[i]
    driver.get(url)
    
    #곡 정보 가져오기
    song_name = driver.find_element_by_css_selector('.song_name').text  #곡이름
    artist = driver.find_element_by_css_selector('.artist').text  #아티스트 이름
    album_name =  driver.find_elements_by_css_selector('.list dd')[0].text  #앨범이름
    date = driver.find_elements_by_css_selector('.list dd')[1].text  #발매일
    genre = driver.find_elements_by_css_selector('.list dd')[2].text  #장르
    like = driver.find_element_by_css_selector('#d_like_count').text  #좋아요 수
    review = driver.find_element_by_css_selector('.d_cmtpgn_srch_cnt').text  #리뷰 수
    
    #곡 정보 추가하기
    result.append({
                'song_name': song_name,
                'artist': artist,
                'album_name': album_name,
                'date': date,
                'genre': genre,
                'like': like,
                'review': review
                })
     
    print(i+1,'번째 곡 완료')
# Out:
# 1 번째 곡 완료
# 2 번째 곡 완료
# 3 번째 곡 완료
# 4 번째 곡 완료
# 5 번째 곡 완료
# 6 번째 곡 완료
# 7 번째 곡 완료
# 8 번째 곡 완료
# 9 번째 곡 완료
# 10 번째 곡 완료
# 11 번째 곡 완료
# 12 번째 곡 완료
# 13 번째 곡 완료
# 14 번째 곡 완료
# 15 번째 곡 완료
# 16 번째 곡 완료
# 17 번째 곡 완료
# 18 번째 곡 완료
# 19 번째 곡 완료
# 20 번째 곡 완료
# 21 번째 곡 완료
# 22 번째 곡 완료
# 23 번째 곡 완료
# 24 번째 곡 완료
# 25 번째 곡 완료
# 26 번째 곡 완료
# 27 번째 곡 완료
# 28 번째 곡 완료
# 29 번째 곡 완료
# 30 번째 곡 완료
# 31 번째 곡 완료
# 32 번째 곡 완료
# 33 번째 곡 완료
# 34 번째 곡 완료
# 35 번째 곡 완료
# 36 번째 곡 완료
# 37 번째 곡 완료
# 38 번째 곡 완료
# 39 번째 곡 완료
# 40 번째 곡 완료
# 41 번째 곡 완료
# 42 번째 곡 완료
# 43 번째 곡 완료
# 44 번째 곡 완료
# 45 번째 곡 완료
# 46 번째 곡 완료
# 47 번째 곡 완료
# 48 번째 곡 완료
# 49 번째 곡 완료
# 50 번째 곡 완료
# 51 번째 곡 완료
# 52 번째 곡 완료
# 53 번째 곡 완료
# 54 번째 곡 완료
# 55 번째 곡 완료
# 56 번째 곡 완료
# 57 번째 곡 완료
# 58 번째 곡 완료
# 59 번째 곡 완료
# 60 번째 곡 완료
# 61 번째 곡 완료
# 62 번째 곡 완료
# 63 번째 곡 완료
# 64 번째 곡 완료
# 65 번째 곡 완료
# 66 번째 곡 완료
# 67 번째 곡 완료
# 68 번째 곡 완료
# 69 번째 곡 완료
# 70 번째 곡 완료
# 71 번째 곡 완료
# 72 번째 곡 완료
# 73 번째 곡 완료
# 74 번째 곡 완료
# 75 번째 곡 완료
# 76 번째 곡 완료
# 77 번째 곡 완료
# 78 번째 곡 완료
# 79 번째 곡 완료
# 80 번째 곡 완료
# 81 번째 곡 완료
# 82 번째 곡 완료
# 83 번째 곡 완료
# 84 번째 곡 완료
# 85 번째 곡 완료
# 86 번째 곡 완료
# 87 번째 곡 완료
# 88 번째 곡 완료
# 89 번째 곡 완료
# 90 번째 곡 완료
# 91 번째 곡 완료
# 92 번째 곡 완료
# 93 번째 곡 완료
# 94 번째 곡 완료
# 95 번째 곡 완료
# 96 번째 곡 완료
# 97 번째 곡 완료
# 98 번째 곡 완료
# 99 번째 곡 완료
# 100 번째 곡 완료

# %%
#데이터프레임으로 만들기
result = pd.DataFrame(result, columns = ['song_name', 'artist', 'album_name', 'date', 'genre','like', 'review'])
result
# Out:
#                                    song_name        artist  \
# 0                                         안녕            폴킴
# 1                          기억해줘요 내 모든 날과 그때를            거미
# 2                                Done For Me    펀치 (Punch)
# 3   오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)  마크툽 (MAKTUB)
# 4                                     그대라는 시  태연 (TAEYEON)
# ..                                       ...           ...
# 95                       여름의 끝자락 (Feat. 김정원)           김동률
# 96                                       어쩌나           세븐틴
# 97                       Don`t Make Me Laugh    오하영 (에이핑크)
# 98                                      BOOM     NCT DREAM
# 99                 Intro (Through the night)          강다니엘
#
#                                     album_name        date           genre  \
# 0                           호텔 델루나 OST Part.10  2019.08.12      발라드, 국내드라마
# 1                            호텔 델루나 OST Part.7  2019.08.04      발라드, 국내드라마
# 2                           호텔 델루나 OST Part.12  2019.08.18      발라드, 국내드라마
# 3                   Red Moon : To You My Light  2019.06.09  R&B/Soul, 인디음악
# 4                            호텔 델루나 OST Part.3  2019.07.21      발라드, 국내드라마
# ..                                         ...         ...             ...
# 95                                     여름의 끝자락  2019.08.20             발라드
# 96  SEVENTEEN 5TH MINI ALBUM `YOU MAKE MY DAY`  2018.07.16              댄스
# 97                                         OH!  2019.08.21              댄스
# 98                We Boom - The 3rd Mini Album  2019.07.26              댄스
# 99                                 color on me  2019.07.25        R&B/Soul
#
#        like review
# 0    57,350    252
# 1    72,901    278
# 2    45,695    535
# 3   101,923    439
# 4   117,908    894
# ..      ...    ...
# 95    6,760     93
# 96   86,851  1,357
# 97    4,974     58
# 98   36,200  2,054
# 99   30,071    148
#
# [100 rows x 7 columns]

# %%
#webdriver를 종료하여 창닫기
driver.close()
