# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('RSB_DbD_fin.csv',encoding='UTF8')

# %%
df_RSB=pd.read_csv('RSB_final.csv', encoding='UTF8')

# %%
df_RSB.columns
# Out:
# Index(['batter_id', 'batter_name', 'year', 'team', 'avg', 'G', 'AB', 'R', 'H',
#        '2B', '3B', 'HR', 'TB', 'RBI', 'SB', 'CS', 'BB', 'HBP', 'SO', 'GDP',
#        'SLG', 'OBP', 'E', 'OPS', 'year_born', 'col_school', 'height', 'weight',
#        'posi', 'ta', 'age', '고4', 'SF', '도실', '루타', '타석', '희타', 'WAR', 'WOBA',
#        'WPA', 'WRC+', 'salary'],
#       dtype='object')

# %%
df_RSB.head(100)
# Out:
#     batter_id batter_name  year team    avg    G   AB   R    H  2B    ...     \
# 0           1         강경학  2011   한화  0.000    2    1   0    0   0    ...
# 1           1         강경학  2014   한화  0.221   41   86  11   19   2    ...
# 2           1         강경학  2015   한화  0.257  120  311  50   80   7    ...
# 3           1         강경학  2016   한화  0.158   46  101  16   16   3    ...
# 4           1         강경학  2017   한화  0.214   59   84  17   18   2    ...
# 5           1         강경학  2018   한화  0.278   77  245  42   68  11    ...
# 6           2         강구성  2013   NC  0.000    2    2   0    0   0    ...
# 7           2         강구성  2015   NC  0.200    4    5   0    1   1    ...
# 8           2         강구성  2016   NC  0.000    2    3   0    0   0    ...
# 9           2         강구성  2017   NC  0.000    1    1   0    0   0    ...
# 10          2         강구성  2018   NC  0.200    4    5   0    1   1    ...
# 11          3         강민국  2014   NC  0.000    6    3   0    0   0    ...
# ...

# %%
df_bi1=df[df['batter_id']==1]
df_RSB_bi1=df[df['batter_id']==1]

# %%
sns.factorplot(x='year', y='OPS',data=df_RSB, palette='plasma', size=10)

# %%
sns.set_style('whitegrid')
sns.barplot(x='batter_name', y='cum_OPS', data=df, palette='hls')

# %%
sns.factorplot(x='batter_name', y='cum_OPS', data=df, palette='plasma', size=10)

# %%
sns.factorplot(x='ymd', y='cum_OPS', data=df_bi1, palette='plasma', size=10)

# %%
sns.barplot(x='opposing_team', y='cum_OPS',data=df_bi1, palette='hls')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'batter_id', 'batter_name', 'opposing_team', 'avg1', 'AB',
#        'R', 'H', '2B', '3B', 'HR', 'RBI', 'SB', 'CS', 'BB', 'HBP', 'SO', 'GDP',
#        'avg2', 'ymd', '1B', 'cum_AB', 'cum_H', 'cum_1B', 'cum_2B', 'cum_3B',
#        'cum_HR', 'cum_BB', 'cum_HBP', 'cum_OPS'],
#       dtype='object')

# %%
df_RSB.groupby('batter_name')['OPS'].describe()
# Out:
#              count      mean       std    min      25%     50%      75%    max
# batter_name
# 강경학            6.0  0.529000  0.278345  0.000  0.50475  0.6125  0.68275  0.774
# 강구성            5.0  0.240000  0.328634  0.000  0.00000  0.0000  0.60000  0.600
# 강민국            4.0  0.251000  0.289834  0.000  0.00000  0.2500  0.50100  0.504
# 강민호           15.0  0.759733  0.238251  0.000  0.74900  0.7880  0.84800  1.060
# 강백호            1.0  0.880000       NaN  0.880  0.88000  0.8800  0.88000  0.880
# 강상원            2.0  0.321500  0.252437  0.143  0.23225  0.3215  0.41075  0.500
# 강승호            3.0  0.609000  0.110436  0.483  0.56900  0.6550  0.67200  0.689
# 강진성            3.0  1.048333  0.567148  0.553  0.73900  0.9250  1.29600  1.667
# 강한울            5.0  0.613600  0.065248  0.508  0.61200  0.6210  0.64300  0.684
# 고명성            1.0  0.000000       NaN  0.000  0.00000  0.0000  0.00000  0.000
# 고종욱            6.0  0.664833  0.263128  0.143  0.68650  0.7600  0.81925  0.825
# ...

# %%
sns.factorplot(data = df_RSB_bi1, x = 'year', y = "OPS", 
               #col = 'StoreType', # per store type in cols
               palette = 'plasma',
               #hue = 'StoreTyp',
               row = 'batter_name', # per promo in the store in rows
               #color = c
              )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-e0bf913c05de> in <module>()
#       3                palette = 'plasma',
#       4                #hue = 'StoreTyp',
# ----> 5                row = 'batter_name', # per promo in the store in rows
#       6                #color = c
#       7               )
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in factorplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, size, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3489     # facets to ensure representation of all data in the final plot
#    3490     p = _CategoricalPlotter()
# -> 3491     p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3492     order = p.group_names
# ...
